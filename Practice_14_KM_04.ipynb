# %% [markdown]
# # **Курс "Програмування на мові Python"**
#
# ##### Викладачі:
# ##### Борисенко Павло Борисович
# ##### Щьоголєв Максим Олегович

# %% [markdown]
# ## **Практичне зайняття №14**
#
# ### Тема: "Робота з файлами"

# %% [markdown]
# ### **Завдання 1 (1,5 бали)**
#
# У 1939 році друком вийшов роман американського письменика Ернеста Вінсента Райта "Ґедсбі". Особливу увагу публіки він здобув через те, що письменник жодного разу не використав у романі літеру "e" (роман складається з більше ніж 50,000 слів), яка є найбільш вживаною літерою в англійській мові.
#
# Порахуйте кількість входжень кожної літери у текст роману. Виведіть список літер англійського алфавіту, а також інформацію про те, скільки відсотків від усіх літер тексту складає кожна літера алфавіту.
#
# Зауваження:
#
# 1. Програма має ігнорувати будь-які символи, окрім літер.
#
# 2. Переведіть усі літери у верхній або у нижній регістр.
#
# 3. Під час виведення відсортуйте літери у порядку зменшення їхнього відсотка. Літера "e" має стояти на останньому місці у цьому списку.
#
# 4. Виведіть перші 5 та останні 5 літер відсортованого списку разом з відсотковими значеннями, що їм відповідають.

# %%
l = list()
for later  in ['q','w','e','r','t','y','u','i','o','p','a','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m']:

    c = 0
    kc = 0
    file = open('gadsby.txt', 'r')
    for line in file:
       line = line.lower()
       c = line.count(later)
       kc += c
    file.close()
    l.append(kc)
ans = list(zip(['q','w','e','r','t','y','u','i','o','p','a','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m'],l))
ans2 = list(zip(l,['q','w','e','r','t','y','u','i','o','p','a','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m']))

dict = {}
for i in ans:
    dict.update(ans)


l.sort()
dict2 = {}
for i in ans2:
    dict2.update(ans2)


l2 = []
for i in  l:
    k = i / (sum(l) / 100)
    l2.append(k)
ans3 = list(zip(l,l2))

dict3 = {}
for i in ans3:
    dict3.update(ans3)
for i in range(len(l)):
  print(dict2[l[i]],' ',round(dict3[l[i]],5),'%')

print("Букви з найменшою кількістю входжень")
for i in range(0,5):
    print('Буква:',dict2[l[i]],' Кількість входжень:',l[i],' Процент від загальної кількості букв:' , round(dict3[l[i]],5),'%')
print("------------------------------------------------","\n")
print("Букви з найбільшою кількістю входжень")
for i in range(1,6):
    print('Буква:',dict2[l[-i]],' Кількість входжень:',l[-i],' Процент від загальної кількості букв:' , round(dict3[l[-i]],5),'%')
# Out:
# e   0.00189 %
# q   0.05139 %
# x   0.0792 %
# z   0.10749 %
# j   0.22959 %
# v   0.32341 %
# k   1.17813 %
# p   1.90416 %
# m   2.07576 %
# b   2.14176 %
# f   2.15213 %
# c   2.66082 %
# w   2.79754 %
# y   3.17516 %
# g   3.60559 %
# d   4.11758 %
# u   4.15812 %
# r   4.7578 %
# h   4.90866 %
# l   5.31881 %
# s   6.96745 %
# t   8.49398 %
# n   8.59722 %
# i   8.8254 %
# o   10.41888 %
# a   10.95208 %
# Букви з найменшою кількістю входжень
# Буква: e  Кількість входжень: 4  Процент від загальної кількості букв: 0.00189 %
# Буква: q  Кількість входжень: 109  Процент від загальної кількості букв: 0.05139 %
# Буква: x  Кількість входжень: 168  Процент від загальної кількості букв: 0.0792 %
# Буква: z  Кількість входжень: 228  Процент від загальної кількості букв: 0.10749 %
# Буква: j  Кількість входжень: 487  Процент від загальної кількості букв: 0.22959 %
# ------------------------------------------------
#
# Букви з найбільшою кількістю входжень
# ...

# %% [markdown]
# ### **Завдання 2 (1,5 бали)**
#
# Створіть CSV-файл, що буде містити від 5 до 10 пісень (творів) вашого улюбленого музиканта. Назва файлу - ім'я музиканта (композитора) або назва гурту.
#
# 1. Обов'язково додайте до файлу рядок з назвами двох колонок (Song, Year) або (Composition, Year).
#
# 2. Після запису файлу роздрукуйте назву файлу та усі наявні у файлі рядки (включно із заголовками).
#
# 3. Для запису та зчитування рядків скористайтесь функціями csv.DictWriter() та csv.DictReader().

# %%
import csv
with open('Max Korzh.csv', 'w', newline='') as csvfile:
    fieldnames = ['Song', 'Year']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({'Song': '«Amsterdam»',
                     'Year': '2014', })
    writer.writerow({'Song': '«Оптимист»',
                     'Year': '2017',})
    writer.writerow({'Song': '«Горы по колено»',
                     'Year': '2018', })
    writer.writerow({'Song': '«Пролетарка»',
                     'Year': '2018', })
    writer.writerow({'Song': '«Контрольный»',
                     'Year': '2019', })
    writer.writerow({'Song': '«Шантаж»',
                     'Year': '2019', })
    writer.writerow({'Song': '«2 типа людей»',
                     'Year': '2019', })
    writer.writerow({'Song': '«Разнесём»',
                     'Year': '2020', })
    writer.writerow({'Song': '«Малолетка»',
                     'Year': '2020', })

with open('Max Korzh.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for heading in reader.fieldnames:
        print(heading, end=' ')
    print('\n-----------')
    for row in reader:
        print(row['Song'], row['Year'])
# Out:
# Song Year
# -----------
# «Amsterdam» 2014
# «Оптимист» 2017
# «Горы по колено» 2018
# «Пролетарка» 2018
# «Контрольный» 2019
# «Шантаж» 2019
# «2 типа людей» 2019
# «Разнесём» 2020
# «Малолетка» 2020

# %% [markdown]
# ### **Завдання 3 (бонусне, 1 бал)**
#
# COCO Dataset - набір фотографій та анотацій до них. Його дуже часто використовують для тренування класифікаторів, призначених для розпізнавання об'єктів та визначення ключових точок на зображеннях.
#
# Завантажте файли з описом фотографій COCO Dataset за посиланням: http://images.cocodataset.org/annotations/image_info_test2017.zip
#
# 1. Відкрийте файл image_info_test-dev2017.json. Інформація про фотографії з бази COCO міститься у полі "images". Інформація про категорії, на які розділені всі фотографії, міститься у полі "categories".
#
# 2. Визначте кількість фотографій, інформацію про які можна знайти у цьому файлі (кількість елементів, що відповідають ключу "images").
#
# 3. Визначте кількість наявних категорій (кількість елементів, що відповідають ключу "categories").
#
# 4. Виведіть посилання на фотографію 000000000001.jpg ("coco_url"), висоту цієї фотографії ("height"), ширину ("width") та її ідентифікатор ("id").
#
# 5. Опис структури JSON-файлу для набору фотографій COCO можна знайти за посиланням: https://cocodataset.org/#format-data
#
# 6. Щоб перевірити правильність результатів, у VS Code встановіть розширення JSON та відкрийте файл image_info_test-dev2017.json. Розширення автоматично визначає кількість елементів у кожному полі.
